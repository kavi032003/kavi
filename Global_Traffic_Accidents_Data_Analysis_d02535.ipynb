# %% [markdown]
# <a href="https://colab.research.google.com/github/kavi032003/kavi/blob/main/Global_Traffic_Accidents_Data_Analysis_d02535.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
adilshamim8_global_traffic_accidents_dataset_path = kagglehub.dataset_download('adilshamim8/global-traffic-accidents-dataset')

print('Data source import complete.')

# %% [markdown]
# <img src="https://ec.europa.eu/eurostat/documents/4187653/15537833/Gorodenkoff_Shutterstock_1721682409_RV.jpg" alt="accident"/>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import ast
from datetime import datetime
import matplotlib.pyplot as plt
import plotly.express as px

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import warnings
warnings.filterwarnings("ignore") # Ignoring warnings
# Out:
# /kaggle/input/global-traffic-accidents-dataset/global_traffic_accidents.csv

# %% [markdown]
# ## Load the dataset and view all lines

# %%
csv = pd.read_csv('/kaggle/input/global-traffic-accidents-dataset/global_traffic_accidents.csv')
accidents_df = pd.DataFrame(csv)
accidents_df
# Out:
#      Accident ID        Date   Time           Location   Latitude   Longitude  \
# 0       b0dd6f57  2023-04-19  06:39      Mumbai, India  13.488432  -73.290682
# 1       debfad09  2023-01-17  02:47  São Paulo, Brazil -37.798317  -32.244242
# 2       6d69aa36  2024-04-09  02:55  Sydney, Australia  33.767869  104.869018
# 3       425bb1f0  2023-10-10  11:23       Tokyo, Japan  -0.378031 -165.825855
# 4       90d5cf62  2023-01-02  12:07     Beijing, China  41.254879  -30.776959
# ...          ...         ...    ...                ...        ...         ...
# 9995    2d26c7e2  2023-01-10  18:41      Paris, France -41.344055  109.335620
# 9996    4d236cfd  2023-04-04  16:48  São Paulo, Brazil -60.765148  -10.432225
# 9997    1d32722f  2024-09-30  14:43     Beijing, China -11.161278  -72.164379
# 9998    64722572  2024-10-27  18:34  Sydney, Australia -17.153524   20.803006
# 9999    96272c1b  2024-10-26  10:30    Toronto, Canada  21.917486  100.486079
#
#      Weather Condition      Road Condition  Vehicles Involved  Casualties  \
# 0                 Snow               Snowy                  5           7
# 1                Clear                 Icy                  4           1
# 2                 Rain               Snowy                  1           7
# 3                Storm                 Wet                  4           0
# 4                Storm               Snowy                  3           9
# ...                ...                 ...                ...         ...
# 9995             Storm                 Wet                  3          10
# 9996             Storm                 Dry                  3           9
# 9997              Snow  Under Construction                  2           3
# 9998             Storm  Under Construction                  4           3
# 9999             Storm                 Icy                  5           4
#
#                    Cause
# 0       Reckless Driving
# 1          Drunk Driving
# 2       Reckless Driving
# 3          Drunk Driving
# 4       Reckless Driving
# ...                  ...
# 9995  Distracted Driving
# 9996  Weather Conditions
# 9997  Weather Conditions
# 9998       Drunk Driving
# 9999  Mechanical Failure
#
# [10000 rows x 11 columns]

# %% [markdown]
# ## Checking the stats

# %%
accidents_df.describe()
# Out:
#            Latitude     Longitude  Vehicles Involved   Casualties
# count  10000.000000  10000.000000       10000.000000  10000.00000
# mean      -0.543557      0.338573           2.999100      4.98820
# std       51.917928    103.379168           1.408935      3.13015
# min      -89.985688   -179.961984           1.000000      0.00000
# 25%      -45.426619    -88.231733           2.000000      2.00000
# 50%       -1.080556     -0.682727           3.000000      5.00000
# 75%       44.137309     89.973059           4.000000      8.00000
# max       89.990081    179.981695           5.000000     10.00000

# %% [markdown]
# ## Checking the column Dtypes

# %%
accidents_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Accident ID        10000 non-null  object
#  1   Date               10000 non-null  object
#  2   Time               10000 non-null  object
#  3   Location           10000 non-null  object
#  4   Latitude           10000 non-null  float64
#  5   Longitude          10000 non-null  float64
#  6   Weather Condition  10000 non-null  object
#  7   Road Condition     10000 non-null  object
#  8   Vehicles Involved  10000 non-null  int64
#  9   Casualties         10000 non-null  int64
#  10  Cause              10000 non-null  object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 859.5+ KB

# %% [markdown]
# ## Checking the null values

# %%
accidents_df.isnull().sum()
# Out:
# Accident ID          0
# Date                 0
# Time                 0
# Location             0
# Latitude             0
# Longitude            0
# Weather Condition    0
# Road Condition       0
# Vehicles Involved    0
# Casualties           0
# Cause                0
# dtype: int64

# %% [markdown]
# ## Weather Condition counts

# %%
accidents_df['Weather Condition'].value_counts()
# Out:
# Weather Condition
# Rain     1681
# Clear    1674
# Hail     1673
# Snow     1667
# Fog      1660
# Storm    1645
# Name: count, dtype: int64

# %%
# Using Seaborn to plot
plot = sns.catplot(accidents_df, x='Weather Condition', hue="Vehicles Involved", kind='count', palette="ch:start=.2,rot=-.3")
plot.figure.set_size_inches(14,6)
plot.set_titles("Count of accidents ")

# %% [markdown]
# ## Quantity and distribution of accidents causes

# %%
accidents_df.Cause.value_counts()
# Out:
# Cause
# Drunk Driving         1716
# Reckless Driving      1685
# Weather Conditions    1657
# Speeding              1656
# Mechanical Failure    1653
# Distracted Driving    1633
# Name: count, dtype: int64

# %%
# Using MatPlotLib to plot frequency distribution
fig, ax = plt.subplots()
ax.pie(accidents_df.Cause.value_counts(), labels=accidents_df.Cause.value_counts().index, autopct='%1.1f%%')
plt.show()

# %%
# Using Seaborn to plot of vehicles involved per causes
plot = sns.histplot(accidents_df, x= "Cause", hue="Vehicles Involved", multiple="dodge", palette="rocket_r", shrink=.8)
plot.figure.set_size_inches(14,5)
plt.show()

# %% [markdown]
# ## Density of casualties per vehicles involvided

# %%
# Using Seaborn to plot
plot = sns.displot(accidents_df, x= "Casualties", hue="Vehicles Involved", kind="kde", multiple="stack", palette="ch:s=-.2,r=.6")
plt.show()

# %% [markdown]
# ## Count of causes per weekday

# %%
# Tranformated 'Date' column to date Dtype
accidents_df['Date']= pd.to_datetime(accidents_df['Date'])
accidents_df.head()
# Out:
#   Accident ID       Date   Time           Location   Latitude   Longitude  \
# 0    b0dd6f57 2023-04-19  06:39      Mumbai, India  13.488432  -73.290682
# 1    debfad09 2023-01-17  02:47  São Paulo, Brazil -37.798317  -32.244242
# 2    6d69aa36 2024-04-09  02:55  Sydney, Australia  33.767869  104.869018
# 3    425bb1f0 2023-10-10  11:23       Tokyo, Japan  -0.378031 -165.825855
# 4    90d5cf62 2023-01-02  12:07     Beijing, China  41.254879  -30.776959
#
#   Weather Condition Road Condition  Vehicles Involved  Casualties  \
# 0              Snow          Snowy                  5           7
# 1             Clear            Icy                  4           1
# 2              Rain          Snowy                  1           7
# 3             Storm            Wet                  4           0
# 4             Storm          Snowy                  3           9
#
#               Cause
# 0  Reckless Driving
# 1     Drunk Driving
# 2  Reckless Driving
# 3     Drunk Driving
# 4  Reckless Driving

# %%
# Creating another dataframe to date manipulate
date_df = accidents_df.copy()
date_df['Month'] = date_df['Date'].dt.month
date_df['Day'] = date_df['Date'].dt.day
date_df['Year'] = date_df['Date'].dt.year

# %%
# Create column Weekday
date_df["Weekday"] = date_df.apply(lambda row: datetime(row["Year"], row["Month"], row["Day"]).strftime('%A'), axis=1)
date_df.head()
# Out:
#   Accident ID       Date   Time           Location   Latitude   Longitude  \
# 0    b0dd6f57 2023-04-19  06:39      Mumbai, India  13.488432  -73.290682
# 1    debfad09 2023-01-17  02:47  São Paulo, Brazil -37.798317  -32.244242
# 2    6d69aa36 2024-04-09  02:55  Sydney, Australia  33.767869  104.869018
# 3    425bb1f0 2023-10-10  11:23       Tokyo, Japan  -0.378031 -165.825855
# 4    90d5cf62 2023-01-02  12:07     Beijing, China  41.254879  -30.776959
#
#   Weather Condition Road Condition  Vehicles Involved  Casualties  \
# 0              Snow          Snowy                  5           7
# 1             Clear            Icy                  4           1
# 2              Rain          Snowy                  1           7
# 3             Storm            Wet                  4           0
# 4             Storm          Snowy                  3           9
#
#               Cause  Month  Day  Year    Weekday
# 0  Reckless Driving      4   19  2023  Wednesday
# 1     Drunk Driving      1   17  2023    Tuesday
# 2  Reckless Driving      4    9  2024    Tuesday
# 3     Drunk Driving     10   10  2023    Tuesday
# 4  Reckless Driving      1    2  2023     Monday

# %%
# Ordered days to plot
orderedDays = pd.CategoricalDtype(["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])
date_df["Weekday"] = date_df["Weekday"].astype(orderedDays)

# %%
# Using Seaborn to plot
plot = sns.catplot(data=date_df,
                   x="Weekday",
                   hue="Cause",
                   kind="count",
                   palette="rocket_r",)
plot.figure.set_size_inches(12,5)
plot.fig.suptitle('Count of causes per weekday', fontsize=20)
plot.set_axis_labels("Weekdays", "Count", fontsize=18)
plt.show()

# %% [markdown]
# ## Correlation between Weekdays and Causes

# %%
correlation = pd.crosstab(date_df.Weekday, date_df.Cause)
plt.figure(figsize=(6,4))
sns.heatmap(correlation, annot=True, cmap="Reds", fmt="d")
plt.title("Correlation between Weekdays and Causes")
plt.ylabel("Weekdays")
plt.xlabel("Causes")
plt.show()

# %% [markdown]
# ### Causes more frequently per weekday
#
# * Monday -> Mechanical Failure
# * Tuesday -> Reckless Driving
# * Wednesday -> Drunk Driving
# * Thursday -> Reckless Driving
# * Friday -> Speeding
# * Saturday -> Drunk Driving
# * Sunday -> Mechanical Failure and Distracted Driving

# %% [markdown]
# ## Accidents per location

# %%
# Location with more accidents
accidents_df['Location'].value_counts()
# Out:
# Location
# São Paulo, Brazil    1032
# New York, USA        1016
# Beijing, China       1014
# Sydney, Australia    1006
# Toronto, Canada      1003
# London, UK           1000
# Paris, France         995
# Tokyo, Japan          989
# Mumbai, India         987
# Berlin, Germany       958
# Name: count, dtype: int64

# %%
# Using Seaborn to plot
plot = sns.catplot(accidents_df,
                   x='Location',
                   kind='count',
                   order=accidents_df.Location.value_counts().index)
plot.figure.set_size_inches(12,5)
plot.set_xticklabels(rotation=10, ha='right')
plt.show()

# %% [markdown]
# ## Mapping all accidents in "São Paulo, Brazil"
# Note: None of points are in São Paulo

# %%
# Creating a dataframe with 'Location', 'Latitude' and 'Longitude' columns where 'Location' = 'São Paulo, Brazil'
sp_df = accidents_df.loc[accidents_df['Location'] == 'São Paulo, Brazil', ['Location', 'Latitude', 'Longitude']].reset_index(drop=True)
sp_df
# Out:
#                Location   Latitude   Longitude
# 0     São Paulo, Brazil -37.798317  -32.244242
# 1     São Paulo, Brazil -39.332739    0.991049
# 2     São Paulo, Brazil  51.568285  -22.209768
# 3     São Paulo, Brazil   0.520167 -170.052320
# 4     São Paulo, Brazil -37.075082   -3.632071
# ...                 ...        ...         ...
# 1027  São Paulo, Brazil -46.378740    4.294878
# 1028  São Paulo, Brazil  83.481857  -83.701844
# 1029  São Paulo, Brazil -37.784977 -123.903311
# 1030  São Paulo, Brazil  17.673898  -53.073675
# 1031  São Paulo, Brazil -60.765148  -10.432225
#
# [1032 rows x 3 columns]

# %% [markdown]
# <img src="https://raw.githubusercontent.com/jvitsilva/Statistics_for_Data-Science/refs/heads/main/assets/newplot.png" alt="accident"/>

# %% [markdown]
# ## Conclusion
#
# The Dataset informs several data to take some insights, such as rain being the weather conditione being more present in accidents or the most common causes are drunk driving, being more frequent on Saturday, and reckless driving on Thursday. On the places that the most accidents occurs, São Paulo stands out little ahead of New York and Beijing, but no city coordinates (latitude, longitude) are corrects.
